# %% [markdown]
# # NLP Lab: Language Models
#
# In this lab, we will build the main components of the GPT-2 model and train a small model on poems by Victor Hugo.
#
# The questions are included in this notebook. To run the training, you will need to modify the `gpt_single_head.py` file, which is also available in the Git repository.
#
# ## Data
#
# The training data consists of a collection of poems by Victor Hugo, sourced from [gutenberg.org](https://www.gutenberg.org/). The dataset is available in the `data` directory.
#
# To reduce model complexity, we will model the text at the character level. Typically, language models process sequences of subwords using [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) such as BPE, SentencePiece, or WordPiece.
#
# #### Questions:
# - Using [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), display the number of unique characters in the text and the frequency of each character.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
counter = collections.Counter(text)
chars = sorted(counter.keys())

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encoding / Decoding
#
# To transform the text into a vector for the neural network, each character must be encoded as an integer.
#
# The following functions perform the encoding and decoding of characters:

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Train/Validation Split
#
# Since the goal is to predict poems, the lines should not be shuffled randomly. Instead, we must preserve the order of the lines in the text and take only the first 90% for training, while using the remaining 10% to monitor learning.
#
# #### Questions:
# - Split the data into `train_data` (90%) and `val_data` (10%) using slicing on the dataset.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

# %% [markdown]
# ### Context
#
# The language model has a parameter that defines the maximum context size to consider when predicting the next character. This context is called `block_size`. The training data consists of sequences of consecutive characters, randomly sampled from the training set, with a length of `block_size`.
#
# If the starting character of the sequence is `i`, then the context sequence is:
# ```python
# x = data[i:i+block_size]
# ```
# And the target value to predict at each position in the context is the next character:
# ```python
# y = data[i+1:i+block_size+1]
# ```

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([15175])
# context is > < target is >c<
# context is > c< target is >h<
# context is > ch< target is >a<
# context is > cha< target is >n<
# context is > chan< target is >t<
# context is > chant< target is > <
# context is > chant < target is >d<
# context is > chant d< target is >e<

# %% [markdown]
# ### Defining Batches
#
# The training batches consist of multiple character sequences randomly sampled from `train_data`. To randomly select a sequence for the batch, we need to randomly pick a starting point in `train_data` and extract the following `block_size` characters. When selecting the starting point, ensure that there are enough characters remaining after it to form a full sequence of `block_size` characters.
#
# #### Questions:
# - Create the batches `x` by selecting `batch_size` sequences of length `block_size` starting from a randomly chosen index `i`. Stack the examples using `torch.stack`.
# - Create the batches `y` by adding the next character following each sequence in `x`. Stack the examples using `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    # select batch_size random starting points
    starting_points = [torch.randint(len(data) - block_size, (1,)).item() for _ in range(batch_size)]
    
    # get sequences of length block_size starting at each point
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    # get the next character after each position in the sequence
    y = torch.stack([data[i+1:i+1+block_size] for i in starting_points])
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### First Model: A Bigram Model
#
# The first model we will implement is a bigram model. It predicts the next character based only on the current character. This model can be stored in a simple matrix: for each character (row), we store the probability distribution over all possible next characters (columns). This can be implemented using a simple [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer in PyTorch.
#
# #### Questions:
# - In the constructor, define an Embedding layer of size `vocab_size × vocab_size`.
# - In the `forward` method, apply the embedding layer to the batch of indices (`x`).
# - In the `forward` method, define the loss as `cross_entropy` between the predictions and the target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            loss = nn.functional.cross_entropy(logits, targets)


        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# ### Model Before Training
#
# At this stage, the model has not yet been trained—it has only been initialized. However, we can already compute the loss on a random batch. Since the weights are initialized with a normal distribution \( N(0,1) \) for each dimension, the expected loss after initialization should be close to `-ln(1/vocab_size)`, as the entropy is maximal.

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'Expected loss {-math.log(1.0/vocab_size)}')
print (f'Computed loss {loss}')
# Out:
# torch.Size([32, 101])
# Expected loss 4.61512051684126
# Computed loss 4.9072675704956055

# %% [markdown]
# ### Using the Model for Prediction
#
# To use the model for prediction, we need to provide an initial character to start the sequence—this is called the prompt. In our case, we can initialize the generation with the newline character (`\n`) to start a new sentence.
#
# #### Questions:
# - Create a prompt as a tensor of size `(1,1)` containing the integer corresponding to the character `\n`.
# - Generate a sequence of 100 characters from this prompt using the functions `m.generate` and `decode`.
# - How does the generated sentence look?

# %%
print (encode(['\n']))
# Create prompt tensor with newline character
idx = torch.tensor([[stoi['\n']]], dtype=torch.long)
# Generate 100 characters using the model
print(decode(m.generate(idx.to(device), max_new_tokens=100)[0].tolist()))
# Out:
# [0]
#
# aG:I
# aéPwÉEl!è2YpÎpKIuU.ôZUwZ_Èt«bN_;c.8(hO1ÀÀhZVèÂmeôW!5«8XRTkRB·3?KÔ)[lmSËûÈ9àxIJxIêScfî-EPuaFR2ÊÆ

# %% [markdown]
# Each character in the sentence looks completely random.

# %% [markdown]
# ### Training
#
# For training, we use the [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) optimizer with a learning rate of `1e-3`. Each training iteration consists of the following steps:
#
# - Generate a batch
# - Apply the neural network (forward pass) and compute the loss: `model(xb, yb)`
# - Compute the gradient (after resetting accumulated gradients): `loss.backward()`
# - Update the parameters: `optimizer.step()`

# %%
max_iters = 10_000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.9457, val loss 4.9904
# step 10: train loss 4.9411, val loss 4.9802
# step 20: train loss 4.9659, val loss 4.9937
# step 30: train loss 4.9479, val loss 4.9502
# step 40: train loss 4.9457, val loss 5.0422
# step 50: train loss 4.8892, val loss 4.8882
# step 60: train loss 4.9383, val loss 4.9303
# step 70: train loss 4.9552, val loss 4.9042
# step 80: train loss 4.9019, val loss 4.9202
# step 90: train loss 4.8643, val loss 4.9443
# step 100: train loss 4.8632, val loss 4.9259
# step 110: train loss 4.8624, val loss 4.9203
# step 120: train loss 4.9045, val loss 4.8722
# step 130: train loss 4.9050, val loss 4.8718
# step 140: train loss 4.8537, val loss 4.8646
# step 150: train loss 4.7814, val loss 4.8681
# step 160: train loss 4.8362, val loss 4.8009
# step 170: train loss 4.8138, val loss 4.8829
# step 180: train loss 4.8141, val loss 4.8450
# step 190: train loss 4.8115, val loss 4.8484
# step 200: train loss 4.7879, val loss 4.8269
# step 210: train loss 4.7945, val loss 4.8553
# step 220: train loss 4.7530, val loss 4.8611
# step 230: train loss 4.7830, val loss 4.8644
# step 240: train loss 4.7009, val loss 4.7963
# step 250: train loss 4.7357, val loss 4.8316
# step 260: train loss 4.7764, val loss 4.8112
# step 270: train loss 4.7627, val loss 4.8101
# step 280: train loss 4.6929, val loss 4.8497
# step 290: train loss 4.7978, val loss 4.7848
# step 300: train loss 4.7579, val loss 4.7305
# step 310: train loss 4.6868, val loss 4.7376
# step 320: train loss 4.6772, val loss 4.7427
# step 330: train loss 4.7094, val loss 4.7331
# step 340: train loss 4.7674, val loss 4.7536
# step 350: train loss 4.7744, val loss 4.7262
# step 360: train loss 4.6450, val loss 4.6879
# step 370: train loss 4.6351, val loss 4.6782
# step 380: train loss 4.6111, val loss 4.6981
# step 390: train loss 4.7040, val loss 4.6715
# step 400: train loss 4.7018, val loss 4.6541
# step 410: train loss 4.5439, val loss 4.6581
# step 420: train loss 4.6401, val loss 4.6754
# step 430: train loss 4.6539, val loss 4.6716
# step 440: train loss 4.6023, val loss 4.6440
# step 450: train loss 4.5758, val loss 4.6279
# step 460: train loss 4.5974, val loss 4.7601
# step 470: train loss 4.5911, val loss 4.6850
# step 480: train loss 4.5347, val loss 4.6172
# step 490: train loss 4.6279, val loss 4.6473
# step 500: train loss 4.5310, val loss 4.5583
# step 510: train loss 4.5487, val loss 4.5818
# step 520: train loss 4.5467, val loss 4.5760
# step 530: train loss 4.5436, val loss 4.6567
# step 540: train loss 4.5239, val loss 4.5329
# step 550: train loss 4.5480, val loss 4.5710
# step 560: train loss 4.4579, val loss 4.5560
# step 570: train loss 4.5726, val loss 4.5616
# step 580: train loss 4.4695, val loss 4.5467
# step 590: train loss 4.4709, val loss 4.4704
# step 600: train loss 4.5167, val loss 4.5034
# step 610: train loss 4.4316, val loss 4.5191
# step 620: train loss 4.4292, val loss 4.5276
# step 630: train loss 4.4228, val loss 4.4510
# step 640: train loss 4.4575, val loss 4.4989
# step 650: train loss 4.5045, val loss 4.4694
# step 660: train loss 4.4060, val loss 4.4816
# step 670: train loss 4.4434, val loss 4.4863
# step 680: train loss 4.4537, val loss 4.4880
# step 690: train loss 4.4836, val loss 4.4417
# step 700: train loss 4.4229, val loss 4.4139
# step 710: train loss 4.3778, val loss 4.4775
# step 720: train loss 4.4121, val loss 4.4409
# step 730: train loss 4.3746, val loss 4.3608
# step 740: train loss 4.3448, val loss 4.4020
# step 750: train loss 4.4676, val loss 4.4248
# step 760: train loss 4.3925, val loss 4.4299
# step 770: train loss 4.3241, val loss 4.3883
# step 780: train loss 4.3033, val loss 4.3893
# step 790: train loss 4.2054, val loss 4.4309
# step 800: train loss 4.3419, val loss 4.4853
# step 810: train loss 4.4122, val loss 4.3628
# step 820: train loss 4.3771, val loss 4.3978
# step 830: train loss 4.2793, val loss 4.3117
# step 840: train loss 4.3462, val loss 4.4299
# step 850: train loss 4.3844, val loss 4.3755
# step 860: train loss 4.3271, val loss 4.3622
# step 870: train loss 4.3463, val loss 4.3054
# step 880: train loss 4.2847, val loss 4.2713
# step 890: train loss 4.2626, val loss 4.3238
# step 900: train loss 4.2812, val loss 4.3105
# step 910: train loss 4.3010, val loss 4.3268
# step 920: train loss 4.2970, val loss 4.3092
# step 930: train loss 4.2843, val loss 4.2885
# step 940: train loss 4.2069, val loss 4.2599
# step 950: train loss 4.2006, val loss 4.3519
# step 960: train loss 4.1468, val loss 4.3181
# step 970: train loss 4.2113, val loss 4.2689
# step 980: train loss 4.1785, val loss 4.2678
# step 990: train loss 4.2858, val loss 4.2357
# step 1000: train loss 4.2015, val loss 4.2345
# step 1010: train loss 4.2710, val loss 4.2083
# step 1020: train loss 4.1682, val loss 4.2532
# step 1030: train loss 4.2120, val loss 4.1979
# step 1040: train loss 4.1908, val loss 4.2706
# step 1050: train loss 4.1624, val loss 4.2305
# step 1060: train loss 4.1895, val loss 4.2882
# step 1070: train loss 4.1347, val loss 4.2525
# step 1080: train loss 4.1683, val loss 4.1853
# step 1090: train loss 4.1671, val loss 4.1641
# step 1100: train loss 4.1744, val loss 4.1531
# step 1110: train loss 4.2102, val loss 4.1491
# step 1120: train loss 4.2112, val loss 4.2589
# step 1130: train loss 4.1284, val loss 4.1531
# step 1140: train loss 4.1782, val loss 4.2028
# step 1150: train loss 4.1139, val loss 4.1319
# step 1160: train loss 4.1469, val loss 4.1352
# step 1170: train loss 4.1366, val loss 4.1315
# step 1180: train loss 4.0841, val loss 4.1496
# step 1190: train loss 4.0984, val loss 4.1060
# step 1200: train loss 4.0586, val loss 4.1896
# step 1210: train loss 4.0050, val loss 4.2122
# step 1220: train loss 4.0554, val loss 4.1354
# step 1230: train loss 4.0638, val loss 4.0757
# step 1240: train loss 4.0826, val loss 4.0580
# step 1250: train loss 4.0858, val loss 4.0579
# step 1260: train loss 4.0446, val loss 4.1611
# step 1270: train loss 4.0031, val loss 4.0792
# step 1280: train loss 4.0268, val loss 4.0879
# step 1290: train loss 4.0048, val loss 4.0254
# step 1300: train loss 4.0577, val loss 4.0514
# step 1310: train loss 4.0480, val loss 4.0097
# step 1320: train loss 4.0047, val loss 4.0537
# step 1330: train loss 4.0443, val loss 4.0964
# step 1340: train loss 3.9937, val loss 4.0566
# step 1350: train loss 3.9760, val loss 4.0898
# step 1360: train loss 4.0305, val loss 4.0416
# step 1370: train loss 3.9404, val loss 4.0687
# step 1380: train loss 4.0116, val loss 3.9452
# step 1390: train loss 4.0628, val loss 4.0670
# step 1400: train loss 3.9568, val loss 4.0481
# step 1410: train loss 4.0441, val loss 3.9572
# step 1420: train loss 3.9415, val loss 4.0045
# step 1430: train loss 3.9340, val loss 3.9747
# step 1440: train loss 3.9535, val loss 3.9831
# step 1450: train loss 3.9300, val loss 4.0162
# step 1460: train loss 3.8966, val loss 3.9565
# step 1470: train loss 3.9979, val loss 4.0020
# step 1480: train loss 4.0047, val loss 3.9156
# step 1490: train loss 3.7988, val loss 3.9490
# step 1500: train loss 3.8776, val loss 4.0302
# step 1510: train loss 3.8786, val loss 3.9910
# step 1520: train loss 3.8923, val loss 4.0146
# step 1530: train loss 3.8353, val loss 3.9988
# step 1540: train loss 3.9259, val loss 3.9175
# step 1550: train loss 3.8355, val loss 3.9464
# step 1560: train loss 3.8632, val loss 3.9718
# step 1570: train loss 3.8940, val loss 3.9168
# step 1580: train loss 3.8580, val loss 3.9474
# step 1590: train loss 3.8594, val loss 3.8925
# step 1600: train loss 3.7784, val loss 3.8257
# step 1610: train loss 3.8336, val loss 3.9958
# step 1620: train loss 3.8034, val loss 3.9547
# step 1630: train loss 3.8782, val loss 3.9616
# step 1640: train loss 3.8093, val loss 3.9149
# step 1650: train loss 3.8500, val loss 3.8464
# step 1660: train loss 3.8363, val loss 3.8960
# step 1670: train loss 3.8239, val loss 3.8958
# step 1680: train loss 3.7673, val loss 3.8982
# step 1690: train loss 3.8376, val loss 3.8342
# step 1700: train loss 3.8786, val loss 3.8655
# step 1710: train loss 3.8026, val loss 3.8439
# step 1720: train loss 3.7786, val loss 3.8165
# step 1730: train loss 3.7965, val loss 3.8774
# step 1740: train loss 3.7077, val loss 3.8252
# step 1750: train loss 3.7909, val loss 3.8194
# step 1760: train loss 3.8169, val loss 3.8785
# step 1770: train loss 3.7372, val loss 3.8774
# step 1780: train loss 3.7264, val loss 3.8590
# step 1790: train loss 3.8247, val loss 3.7941
# step 1800: train loss 3.6165, val loss 3.7844
# step 1810: train loss 3.6646, val loss 3.7263
# step 1820: train loss 3.8404, val loss 3.8228
# step 1830: train loss 3.8143, val loss 3.8213
# step 1840: train loss 3.7492, val loss 3.7354
# step 1850: train loss 3.7072, val loss 3.8244
# step 1860: train loss 3.7589, val loss 3.8049
# step 1870: train loss 3.7227, val loss 3.7731
# step 1880: train loss 3.7593, val loss 3.7750
# step 1890: train loss 3.7421, val loss 3.7461
# step 1900: train loss 3.6352, val loss 3.8444
# step 1910: train loss 3.6535, val loss 3.6896
# step 1920: train loss 3.6834, val loss 3.7735
# step 1930: train loss 3.6513, val loss 3.7583
# step 1940: train loss 3.6686, val loss 3.7753
# step 1950: train loss 3.6880, val loss 3.6543
# step 1960: train loss 3.6701, val loss 3.7300
# step 1970: train loss 3.6400, val loss 3.6456
# step 1980: train loss 3.7306, val loss 3.7274
# step 1990: train loss 3.6708, val loss 3.7566
# step 2000: train loss 3.6166, val loss 3.7165
# step 2010: train loss 3.5711, val loss 3.6552
# step 2020: train loss 3.6351, val loss 3.6976
# step 2030: train loss 3.6734, val loss 3.7631
# step 2040: train loss 3.5901, val loss 3.7364
# step 2050: train loss 3.6709, val loss 3.7197
# step 2060: train loss 3.6121, val loss 3.6541
# step 2070: train loss 3.5855, val loss 3.7132
# step 2080: train loss 3.6162, val loss 3.5897
# step 2090: train loss 3.5412, val loss 3.6249
# step 2100: train loss 3.5442, val loss 3.6408
# step 2110: train loss 3.5829, val loss 3.5333
# step 2120: train loss 3.6150, val loss 3.6999
# step 2130: train loss 3.6725, val loss 3.6265
# step 2140: train loss 3.5211, val loss 3.6778
# step 2150: train loss 3.6119, val loss 3.6017
# step 2160: train loss 3.6128, val loss 3.6811
# step 2170: train loss 3.6086, val loss 3.6189
# step 2180: train loss 3.5130, val loss 3.6000
# step 2190: train loss 3.6529, val loss 3.6087
# step 2200: train loss 3.4916, val loss 3.5705
# step 2210: train loss 3.5503, val loss 3.6361
# step 2220: train loss 3.5233, val loss 3.5644
# step 2230: train loss 3.5842, val loss 3.5335
# step 2240: train loss 3.4651, val loss 3.6435
# step 2250: train loss 3.6202, val loss 3.6637
# step 2260: train loss 3.5098, val loss 3.6803
# step 2270: train loss 3.5075, val loss 3.5436
# step 2280: train loss 3.5359, val loss 3.5866
# step 2290: train loss 3.5129, val loss 3.5194
# step 2300: train loss 3.5432, val loss 3.6276
# step 2310: train loss 3.5167, val loss 3.6074
# step 2320: train loss 3.4246, val loss 3.5138
# step 2330: train loss 3.4700, val loss 3.5888
# step 2340: train loss 3.4849, val loss 3.6344
# step 2350: train loss 3.4382, val loss 3.5675
# step 2360: train loss 3.5269, val loss 3.5120
# step 2370: train loss 3.4121, val loss 3.5253
# step 2380: train loss 3.5796, val loss 3.5387
# step 2390: train loss 3.4842, val loss 3.5239
# step 2400: train loss 3.4203, val loss 3.6039
# step 2410: train loss 3.4991, val loss 3.4911
# step 2420: train loss 3.4500, val loss 3.5115
# step 2430: train loss 3.4133, val loss 3.4008
# step 2440: train loss 3.4521, val loss 3.4674
# step 2450: train loss 3.4415, val loss 3.5698
# step 2460: train loss 3.4365, val loss 3.5084
# step 2470: train loss 3.4759, val loss 3.6348
# step 2480: train loss 3.4460, val loss 3.4988
# step 2490: train loss 3.4413, val loss 3.5181
# step 2500: train loss 3.4667, val loss 3.5166
# step 2510: train loss 3.4216, val loss 3.5390
# step 2520: train loss 3.4470, val loss 3.4635
# step 2530: train loss 3.4254, val loss 3.5035
# step 2540: train loss 3.4132, val loss 3.4934
# step 2550: train loss 3.4605, val loss 3.4563
# step 2560: train loss 3.3353, val loss 3.4561
# step 2570: train loss 3.3873, val loss 3.4365
# step 2580: train loss 3.3475, val loss 3.5171
# step 2590: train loss 3.4219, val loss 3.3878
# step 2600: train loss 3.4316, val loss 3.4048
# step 2610: train loss 3.4039, val loss 3.4441
# step 2620: train loss 3.4066, val loss 3.4791
# step 2630: train loss 3.4042, val loss 3.5129
# step 2640: train loss 3.3227, val loss 3.4695
# step 2650: train loss 3.3412, val loss 3.4919
# step 2660: train loss 3.3134, val loss 3.4270
# step 2670: train loss 3.3662, val loss 3.4294
# step 2680: train loss 3.3521, val loss 3.5389
# step 2690: train loss 3.3512, val loss 3.4088
# step 2700: train loss 3.3125, val loss 3.3127
# step 2710: train loss 3.3805, val loss 3.4299
# step 2720: train loss 3.3353, val loss 3.4399
# step 2730: train loss 3.3532, val loss 3.5740
# step 2740: train loss 3.3759, val loss 3.3750
# step 2750: train loss 3.2558, val loss 3.3869
# step 2760: train loss 3.3018, val loss 3.4550
# step 2770: train loss 3.3215, val loss 3.4571
# step 2780: train loss 3.3330, val loss 3.4213
# step 2790: train loss 3.2839, val loss 3.4058
# step 2800: train loss 3.3773, val loss 3.3684
# step 2810: train loss 3.3368, val loss 3.4294
# step 2820: train loss 3.3296, val loss 3.4066
# step 2830: train loss 3.3063, val loss 3.3970
# step 2840: train loss 3.3163, val loss 3.4510
# step 2850: train loss 3.3074, val loss 3.3172
# step 2860: train loss 3.2609, val loss 3.4275
# step 2870: train loss 3.3765, val loss 3.4657
# step 2880: train loss 3.3375, val loss 3.4155
# step 2890: train loss 3.2786, val loss 3.4094
# step 2900: train loss 3.2737, val loss 3.4492
# step 2910: train loss 3.2553, val loss 3.3267
# step 2920: train loss 3.3583, val loss 3.3389
# step 2930: train loss 3.3138, val loss 3.3115
# step 2940: train loss 3.3287, val loss 3.4099
# step 2950: train loss 3.1959, val loss 3.3260
# step 2960: train loss 3.1703, val loss 3.3662
# step 2970: train loss 3.2800, val loss 3.3484
# step 2980: train loss 3.3159, val loss 3.3131
# step 2990: train loss 3.1912, val loss 3.3853
# step 3000: train loss 3.2955, val loss 3.2944
# step 3010: train loss 3.2958, val loss 3.3947
# step 3020: train loss 3.3139, val loss 3.2809
# step 3030: train loss 3.2977, val loss 3.3541
# step 3040: train loss 3.2230, val loss 3.3496
# step 3050: train loss 3.2823, val loss 3.4225
# step 3060: train loss 3.2978, val loss 3.3077
# step 3070: train loss 3.2293, val loss 3.3091
# step 3080: train loss 3.2782, val loss 3.2840
# step 3090: train loss 3.2154, val loss 3.2013
# step 3100: train loss 3.2471, val loss 3.3219
# step 3110: train loss 3.2086, val loss 3.2514
# step 3120: train loss 3.1443, val loss 3.2924
# step 3130: train loss 3.2112, val loss 3.3269
# step 3140: train loss 3.1373, val loss 3.3844
# step 3150: train loss 3.2145, val loss 3.3744
# step 3160: train loss 3.2279, val loss 3.2424
# step 3170: train loss 3.2135, val loss 3.3006
# step 3180: train loss 3.1919, val loss 3.2827
# step 3190: train loss 3.1582, val loss 3.3117
# step 3200: train loss 3.2870, val loss 3.2891
# step 3210: train loss 3.2768, val loss 3.3202
# step 3220: train loss 3.2305, val loss 3.2385
# step 3230: train loss 3.2175, val loss 3.2434
# step 3240: train loss 3.2000, val loss 3.2304
# step 3250: train loss 3.1686, val loss 3.2670
# step 3260: train loss 3.2132, val loss 3.2006
# step 3270: train loss 3.2251, val loss 3.2800
# step 3280: train loss 3.2009, val loss 3.3834
# step 3290: train loss 3.1615, val loss 3.1845
# step 3300: train loss 3.1275, val loss 3.2565
# step 3310: train loss 3.1744, val loss 3.2456
# step 3320: train loss 3.1410, val loss 3.2223
# step 3330: train loss 3.1846, val loss 3.2027
# step 3340: train loss 3.1731, val loss 3.2275
# step 3350: train loss 3.1673, val loss 3.1097
# step 3360: train loss 3.0948, val loss 3.1798
# step 3370: train loss 3.1221, val loss 3.1482
# step 3380: train loss 3.1038, val loss 3.2032
# step 3390: train loss 3.1496, val loss 3.2809
# step 3400: train loss 3.1105, val loss 3.2112
# step 3410: train loss 3.1365, val loss 3.3069
# step 3420: train loss 3.1111, val loss 3.2582
# step 3430: train loss 3.1044, val loss 3.2482
# step 3440: train loss 3.1427, val loss 3.2510
# step 3450: train loss 3.1039, val loss 3.2565
# step 3460: train loss 3.1046, val loss 3.1585
# step 3470: train loss 3.1358, val loss 3.2247
# step 3480: train loss 3.1430, val loss 3.2702
# step 3490: train loss 3.2059, val loss 3.2102
# step 3500: train loss 3.0745, val loss 3.2793
# step 3510: train loss 3.1637, val loss 3.1638
# step 3520: train loss 3.0192, val loss 3.2225
# step 3530: train loss 3.1170, val loss 3.1672
# step 3540: train loss 3.0585, val loss 3.1714
# step 3550: train loss 3.1126, val loss 3.2213
# step 3560: train loss 3.1281, val loss 3.2046
# step 3570: train loss 3.0604, val loss 3.2495
# step 3580: train loss 3.1311, val loss 3.2504
# step 3590: train loss 3.0570, val loss 3.2461
# step 3600: train loss 3.0901, val loss 3.1790
# step 3610: train loss 3.0376, val loss 3.1127
# step 3620: train loss 3.1177, val loss 3.1146
# step 3630: train loss 3.1062, val loss 3.0916
# step 3640: train loss 3.0899, val loss 3.1544
# step 3650: train loss 3.0993, val loss 3.1491
# step 3660: train loss 3.0301, val loss 3.1978
# step 3670: train loss 3.0801, val loss 3.2076
# step 3680: train loss 3.0455, val loss 3.1331
# step 3690: train loss 3.0447, val loss 3.2540
# step 3700: train loss 3.0649, val loss 3.1287
# step 3710: train loss 3.0723, val loss 3.2280
# step 3720: train loss 3.0855, val loss 3.1891
# step 3730: train loss 3.0365, val loss 3.2351
# step 3740: train loss 3.0065, val loss 3.1656
# step 3750: train loss 3.0915, val loss 3.1857
# step 3760: train loss 3.0188, val loss 3.1421
# step 3770: train loss 3.0186, val loss 3.1545
# step 3780: train loss 3.0434, val loss 3.1110
# step 3790: train loss 3.0589, val loss 3.1909
# step 3800: train loss 3.0286, val loss 3.1269
# step 3810: train loss 2.9596, val loss 3.1273
# step 3820: train loss 2.9677, val loss 3.1043
# step 3830: train loss 3.0192, val loss 3.1262
# step 3840: train loss 3.0257, val loss 3.1475
# step 3850: train loss 3.0561, val loss 3.1791
# step 3860: train loss 3.0985, val loss 3.1798
# step 3870: train loss 3.0000, val loss 3.2080
# step 3880: train loss 3.0348, val loss 3.0642
# step 3890: train loss 3.0330, val loss 3.0367
# step 3900: train loss 3.0462, val loss 3.1006
# step 3910: train loss 3.0097, val loss 3.1165
# step 3920: train loss 3.0639, val loss 3.0879
# step 3930: train loss 3.0170, val loss 3.1559
# step 3940: train loss 3.0465, val loss 3.0205
# step 3950: train loss 3.0895, val loss 3.1092
# step 3960: train loss 3.0147, val loss 3.1019
# step 3970: train loss 3.0244, val loss 3.1684
# step 3980: train loss 2.9617, val loss 3.1110
# step 3990: train loss 2.9790, val loss 3.0262
# step 4000: train loss 2.9749, val loss 3.0859
# step 4010: train loss 2.9956, val loss 3.2032
# step 4020: train loss 3.0315, val loss 3.1526
# step 4030: train loss 3.0769, val loss 3.0248
# step 4040: train loss 2.8955, val loss 3.1704
# step 4050: train loss 3.0184, val loss 3.1031
# step 4060: train loss 3.0277, val loss 3.1648
# step 4070: train loss 3.0102, val loss 3.1505
# step 4080: train loss 3.0116, val loss 3.1068
# step 4090: train loss 2.9990, val loss 3.1068
# step 4100: train loss 3.0299, val loss 3.0246
# step 4110: train loss 2.9525, val loss 3.0446
# step 4120: train loss 2.9925, val loss 3.1230
# step 4130: train loss 3.0405, val loss 3.0403
# step 4140: train loss 2.9867, val loss 3.0613
# step 4150: train loss 2.9617, val loss 2.9976
# step 4160: train loss 2.9887, val loss 3.0590
# step 4170: train loss 2.9945, val loss 3.0094
# step 4180: train loss 2.9808, val loss 3.0034
# step 4190: train loss 3.0414, val loss 3.1028
# step 4200: train loss 2.8910, val loss 3.1410
# step 4210: train loss 3.0163, val loss 3.1280
# step 4220: train loss 2.9862, val loss 3.0507
# step 4230: train loss 2.9083, val loss 3.0403
# step 4240: train loss 2.9152, val loss 3.0584
# step 4250: train loss 3.0541, val loss 3.0813
# step 4260: train loss 2.9205, val loss 2.9884
# step 4270: train loss 2.8983, val loss 3.0379
# step 4280: train loss 2.9142, val loss 2.9756
# step 4290: train loss 2.8954, val loss 3.0184
# step 4300: train loss 2.9402, val loss 2.9872
# step 4310: train loss 3.0423, val loss 3.0806
# step 4320: train loss 2.9037, val loss 3.0566
# step 4330: train loss 3.0195, val loss 3.0857
# step 4340: train loss 2.9569, val loss 3.1069
# step 4350: train loss 2.8683, val loss 3.0987
# step 4360: train loss 2.9304, val loss 3.0119
# step 4370: train loss 2.9278, val loss 3.0500
# step 4380: train loss 2.8916, val loss 3.0569
# step 4390: train loss 2.8776, val loss 2.9982
# step 4400: train loss 2.9221, val loss 2.9716
# step 4410: train loss 2.9416, val loss 3.1600
# step 4420: train loss 2.9030, val loss 2.9899
# step 4430: train loss 2.9034, val loss 2.9904
# step 4440: train loss 2.8471, val loss 2.9432
# step 4450: train loss 2.9108, val loss 3.0355
# step 4460: train loss 2.9075, val loss 3.0331
# step 4470: train loss 2.9433, val loss 2.9925
# step 4480: train loss 2.8786, val loss 3.0624
# step 4490: train loss 2.9046, val loss 2.9904
# step 4500: train loss 2.8503, val loss 2.9366
# step 4510: train loss 2.8843, val loss 2.9377
# step 4520: train loss 2.9078, val loss 2.9737
# step 4530: train loss 2.8310, val loss 3.1071
# step 4540: train loss 2.8922, val loss 3.0312
# step 4550: train loss 2.8769, val loss 2.9127
# step 4560: train loss 2.8345, val loss 3.0371
# step 4570: train loss 2.9032, val loss 3.0144
# step 4580: train loss 2.9392, val loss 3.0451
# step 4590: train loss 2.9269, val loss 3.0960
# step 4600: train loss 2.8324, val loss 3.0342
# step 4610: train loss 2.8132, val loss 2.9623
# step 4620: train loss 2.9192, val loss 3.0120
# step 4630: train loss 2.8408, val loss 3.0996
# step 4640: train loss 2.9250, val loss 2.9780
# step 4650: train loss 2.8953, val loss 2.9706
# step 4660: train loss 2.8710, val loss 2.9736
# step 4670: train loss 2.8583, val loss 3.0254
# step 4680: train loss 2.9612, val loss 2.9244
# step 4690: train loss 2.7942, val loss 2.9801
# step 4700: train loss 2.8761, val loss 2.9899
# step 4710: train loss 2.7845, val loss 3.0091
# step 4720: train loss 2.8398, val loss 2.9473
# step 4730: train loss 2.8219, val loss 2.9730
# step 4740: train loss 2.9327, val loss 2.9928
# step 4750: train loss 2.9302, val loss 2.7942
# step 4760: train loss 2.8879, val loss 2.9881
# step 4770: train loss 2.8038, val loss 2.9687
# step 4780: train loss 2.8191, val loss 2.9915
# step 4790: train loss 2.8497, val loss 2.9453
# step 4800: train loss 2.9550, val loss 2.9859
# step 4810: train loss 2.8986, val loss 2.8712
# step 4820: train loss 2.8405, val loss 2.9593
# step 4830: train loss 2.9721, val loss 2.9828
# step 4840: train loss 2.8555, val loss 2.8932
# step 4850: train loss 2.8364, val loss 3.0265
# step 4860: train loss 2.8389, val loss 3.0487
# step 4870: train loss 2.8625, val loss 2.8601
# step 4880: train loss 2.9024, val loss 2.9345
# step 4890: train loss 2.8353, val loss 2.8894
# step 4900: train loss 2.8267, val loss 2.8606
# step 4910: train loss 2.8280, val loss 2.9295
# step 4920: train loss 2.8530, val loss 2.9950
# step 4930: train loss 2.8816, val loss 2.8706
# step 4940: train loss 2.8508, val loss 3.0624
# step 4950: train loss 2.8915, val loss 2.9302
# step 4960: train loss 2.8837, val loss 2.9375
# step 4970: train loss 2.8746, val loss 2.9972
# step 4980: train loss 2.7954, val loss 2.9225
# step 4990: train loss 2.7770, val loss 2.9097
# step 5000: train loss 2.8395, val loss 2.9578
# step 5010: train loss 2.7138, val loss 2.9382
# step 5020: train loss 2.8125, val loss 2.9130
# step 5030: train loss 2.8338, val loss 2.9249
# step 5040: train loss 2.8072, val loss 2.8595
# step 5050: train loss 2.8594, val loss 2.9569
# step 5060: train loss 2.8111, val loss 2.9267
# step 5070: train loss 2.7963, val loss 2.9042
# step 5080: train loss 2.8396, val loss 2.9022
# step 5090: train loss 2.8351, val loss 2.8756
# step 5100: train loss 2.8395, val loss 2.9249
# step 5110: train loss 2.8093, val loss 2.9742
# step 5120: train loss 2.7518, val loss 2.9819
# step 5130: train loss 2.8043, val loss 2.9827
# step 5140: train loss 2.8301, val loss 2.8329
# step 5150: train loss 2.8890, val loss 2.8599
# step 5160: train loss 2.8135, val loss 2.7953
# step 5170: train loss 2.7646, val loss 2.9148
# step 5180: train loss 2.8139, val loss 2.8683
# step 5190: train loss 2.7436, val loss 2.9107
# step 5200: train loss 2.8435, val loss 2.8889
# step 5210: train loss 2.7138, val loss 2.9101
# step 5220: train loss 2.8745, val loss 2.8226
# step 5230: train loss 2.7682, val loss 2.8931
# step 5240: train loss 2.7947, val loss 2.9896
# step 5250: train loss 2.8721, val loss 2.8979
# step 5260: train loss 2.7376, val loss 2.8644
# step 5270: train loss 2.7858, val loss 2.9097
# step 5280: train loss 2.8160, val loss 2.8552
# step 5290: train loss 2.7703, val loss 2.8699
# step 5300: train loss 2.8076, val loss 2.9071
# step 5310: train loss 2.8520, val loss 2.9429
# step 5320: train loss 2.8008, val loss 2.9521
# step 5330: train loss 2.7723, val loss 2.8547
# step 5340: train loss 2.7530, val loss 2.9254
# step 5350: train loss 2.7859, val loss 2.8702
# step 5360: train loss 2.7813, val loss 3.0140
# step 5370: train loss 2.7673, val loss 2.9616
# step 5380: train loss 2.8283, val loss 2.8861
# step 5390: train loss 2.7372, val loss 2.8935
# step 5400: train loss 2.7556, val loss 2.8621
# step 5410: train loss 2.8135, val loss 2.8929
# step 5420: train loss 2.7714, val loss 2.9817
# step 5430: train loss 2.7644, val loss 2.8994
# step 5440: train loss 2.7706, val loss 2.8719
# step 5450: train loss 2.7563, val loss 2.9561
# step 5460: train loss 2.7824, val loss 2.9119
# step 5470: train loss 2.7826, val loss 2.8675
# step 5480: train loss 2.7935, val loss 2.9020
# step 5490: train loss 2.6906, val loss 2.9443
# step 5500: train loss 2.7875, val loss 2.7942
# step 5510: train loss 2.7832, val loss 2.8325
# step 5520: train loss 2.8187, val loss 2.9548
# step 5530: train loss 2.7464, val loss 2.8732
# step 5540: train loss 2.7399, val loss 2.8057
# step 5550: train loss 2.7952, val loss 2.9466
# step 5560: train loss 2.7143, val loss 2.8201
# step 5570: train loss 2.7137, val loss 2.8624
# step 5580: train loss 2.7390, val loss 2.9510
# step 5590: train loss 2.6960, val loss 2.8230
# step 5600: train loss 2.7852, val loss 2.9848
# step 5610: train loss 2.6590, val loss 2.9127
# step 5620: train loss 2.6756, val loss 2.8503
# step 5630: train loss 2.6831, val loss 2.8732
# step 5640: train loss 2.7446, val loss 2.8591
# step 5650: train loss 2.7433, val loss 2.8558
# step 5660: train loss 2.6730, val loss 2.7540
# step 5670: train loss 2.7305, val loss 2.8187
# step 5680: train loss 2.7941, val loss 2.8464
# step 5690: train loss 2.7665, val loss 2.7636
# step 5700: train loss 2.7597, val loss 2.9025
# step 5710: train loss 2.8549, val loss 2.9218
# step 5720: train loss 2.7392, val loss 2.8102
# step 5730: train loss 2.7728, val loss 2.7384
# step 5740: train loss 2.6949, val loss 2.8703
# step 5750: train loss 2.7040, val loss 2.7727
# step 5760: train loss 2.6441, val loss 2.8010
# step 5770: train loss 2.7442, val loss 2.8049
# step 5780: train loss 2.6849, val loss 2.9477
# step 5790: train loss 2.7547, val loss 2.9212
# step 5800: train loss 2.7971, val loss 2.8058
# step 5810: train loss 2.7255, val loss 2.8671
# step 5820: train loss 2.7565, val loss 2.7396
# step 5830: train loss 2.7091, val loss 2.9714
# step 5840: train loss 2.7020, val loss 2.8117
# step 5850: train loss 2.7032, val loss 2.7601
# step 5860: train loss 2.8084, val loss 2.7248
# step 5870: train loss 2.7111, val loss 2.8468
# step 5880: train loss 2.7713, val loss 2.7839
# step 5890: train loss 2.6723, val loss 2.6911
# step 5900: train loss 2.7080, val loss 2.7520
# step 5910: train loss 2.6755, val loss 2.7389
# step 5920: train loss 2.6007, val loss 2.8035
# step 5930: train loss 2.7608, val loss 2.8436
# step 5940: train loss 2.7023, val loss 2.7689
# step 5950: train loss 2.7623, val loss 2.9262
# step 5960: train loss 2.7302, val loss 2.7505
# step 5970: train loss 2.7353, val loss 2.8301
# step 5980: train loss 2.7064, val loss 2.7730
# step 5990: train loss 2.7578, val loss 2.7234
# step 6000: train loss 2.8120, val loss 2.8321
# step 6010: train loss 2.7693, val loss 2.7410
# step 6020: train loss 2.8212, val loss 2.7214
# step 6030: train loss 2.6652, val loss 2.8268
# step 6040: train loss 2.7037, val loss 2.8666
# step 6050: train loss 2.6788, val loss 2.7433
# step 6060: train loss 2.6825, val loss 2.8091
# step 6070: train loss 2.6806, val loss 2.8841
# step 6080: train loss 2.7392, val loss 2.8178
# step 6090: train loss 2.6791, val loss 2.8124
# step 6100: train loss 2.6486, val loss 2.8556
# step 6110: train loss 2.6369, val loss 2.6436
# step 6120: train loss 2.7553, val loss 2.6834
# step 6130: train loss 2.6428, val loss 2.8118
# step 6140: train loss 2.6701, val loss 2.7919
# step 6150: train loss 2.7195, val loss 2.7101
# step 6160: train loss 2.7150, val loss 2.8770
# step 6170: train loss 2.6991, val loss 2.7182
# step 6180: train loss 2.6078, val loss 2.7635
# step 6190: train loss 2.7542, val loss 2.7375
# step 6200: train loss 2.7880, val loss 2.7019
# step 6210: train loss 2.6863, val loss 2.8029
# step 6220: train loss 2.7707, val loss 2.8629
# step 6230: train loss 2.6838, val loss 2.7273
# step 6240: train loss 2.6486, val loss 2.7728
# step 6250: train loss 2.6844, val loss 2.7460
# step 6260: train loss 2.8033, val loss 2.8570
# step 6270: train loss 2.5973, val loss 2.7362
# step 6280: train loss 2.6852, val loss 2.8252
# step 6290: train loss 2.7428, val loss 2.7422
# step 6300: train loss 2.6306, val loss 2.7762
# step 6310: train loss 2.6823, val loss 2.7343
# step 6320: train loss 2.6263, val loss 2.8016
# step 6330: train loss 2.7258, val loss 2.8732
# step 6340: train loss 2.6420, val loss 2.7963
# step 6350: train loss 2.6266, val loss 2.8514
# step 6360: train loss 2.6306, val loss 2.8630
# step 6370: train loss 2.7918, val loss 2.8395
# step 6380: train loss 2.7108, val loss 2.9153
# step 6390: train loss 2.6824, val loss 2.7662
# step 6400: train loss 2.7011, val loss 2.7533
# step 6410: train loss 2.6745, val loss 2.7833
# step 6420: train loss 2.7395, val loss 2.7753
# step 6430: train loss 2.7203, val loss 2.6102
# step 6440: train loss 2.7020, val loss 2.7760
# step 6450: train loss 2.7289, val loss 2.8623
# step 6460: train loss 2.6591, val loss 2.7571
# step 6470: train loss 2.6356, val loss 2.7009
# step 6480: train loss 2.6381, val loss 2.6797
# step 6490: train loss 2.6631, val loss 2.8394
# step 6500: train loss 2.6245, val loss 2.7452
# step 6510: train loss 2.6308, val loss 2.6886
# step 6520: train loss 2.5920, val loss 2.8210
# step 6530: train loss 2.6382, val loss 2.7775
# step 6540: train loss 2.6525, val loss 2.6709
# step 6550: train loss 2.6528, val loss 2.6950
# step 6560: train loss 2.7018, val loss 2.7262
# step 6570: train loss 2.6256, val loss 2.7066
# step 6580: train loss 2.7109, val loss 2.7480
# step 6590: train loss 2.6556, val loss 2.8158
# step 6600: train loss 2.7083, val loss 2.8756
# step 6610: train loss 2.6729, val loss 2.8467
# step 6620: train loss 2.7294, val loss 2.8244
# step 6630: train loss 2.7363, val loss 2.7304
# step 6640: train loss 2.6629, val loss 2.7210
# step 6650: train loss 2.6984, val loss 2.7561
# step 6660: train loss 2.6965, val loss 2.7731
# step 6670: train loss 2.7197, val loss 2.7157
# step 6680: train loss 2.5945, val loss 2.6958
# step 6690: train loss 2.6655, val loss 2.7573
# step 6700: train loss 2.6340, val loss 2.7918
# step 6710: train loss 2.6476, val loss 2.6822
# step 6720: train loss 2.6707, val loss 2.7471
# step 6730: train loss 2.6727, val loss 2.7774
# step 6740: train loss 2.6631, val loss 2.7827
# step 6750: train loss 2.5944, val loss 2.8094
# step 6760: train loss 2.6184, val loss 2.7788
# step 6770: train loss 2.6283, val loss 2.7687
# step 6780: train loss 2.7179, val loss 2.6838
# step 6790: train loss 2.5495, val loss 2.7762
# step 6800: train loss 2.6230, val loss 2.7465
# step 6810: train loss 2.6002, val loss 2.9306
# step 6820: train loss 2.6451, val loss 2.6744
# step 6830: train loss 2.6235, val loss 2.8624
# step 6840: train loss 2.6151, val loss 2.7487
# step 6850: train loss 2.6413, val loss 2.6659
# step 6860: train loss 2.5735, val loss 2.7113
# step 6870: train loss 2.6448, val loss 2.6702
# step 6880: train loss 2.7093, val loss 2.7465
# step 6890: train loss 2.6653, val loss 2.6781
# step 6900: train loss 2.5502, val loss 2.8178
# step 6910: train loss 2.5996, val loss 2.7224
# step 6920: train loss 2.6644, val loss 2.7260
# step 6930: train loss 2.6372, val loss 2.7650
# step 6940: train loss 2.6160, val loss 2.6632
# step 6950: train loss 2.6059, val loss 2.7095
# step 6960: train loss 2.6687, val loss 2.7634
# step 6970: train loss 2.5699, val loss 2.6958
# step 6980: train loss 2.5903, val loss 2.7193
# step 6990: train loss 2.6276, val loss 2.7662
# step 7000: train loss 2.6816, val loss 2.6840
# step 7010: train loss 2.6439, val loss 2.7054
# step 7020: train loss 2.6693, val loss 2.7089
# step 7030: train loss 2.5899, val loss 2.7241
# step 7040: train loss 2.5610, val loss 2.7803
# step 7050: train loss 2.6409, val loss 2.5994
# step 7060: train loss 2.6621, val loss 2.7191
# step 7070: train loss 2.6167, val loss 2.7278
# step 7080: train loss 2.5735, val loss 2.5691
# step 7090: train loss 2.5601, val loss 2.6058
# step 7100: train loss 2.6834, val loss 2.7841
# step 7110: train loss 2.6093, val loss 2.6673
# step 7120: train loss 2.6552, val loss 2.7243
# step 7130: train loss 2.6046, val loss 2.6906
# step 7140: train loss 2.7093, val loss 2.6944
# step 7150: train loss 2.5881, val loss 2.7296
# step 7160: train loss 2.7399, val loss 2.7054
# step 7170: train loss 2.5763, val loss 2.7270
# step 7180: train loss 2.5924, val loss 2.8242
# step 7190: train loss 2.5436, val loss 2.6627
# step 7200: train loss 2.5429, val loss 2.6876
# step 7210: train loss 2.6392, val loss 2.7695
# step 7220: train loss 2.6378, val loss 2.7320
# step 7230: train loss 2.6458, val loss 2.7327
# step 7240: train loss 2.6620, val loss 2.7918
# step 7250: train loss 2.6147, val loss 2.5852
# step 7260: train loss 2.5381, val loss 2.8032
# step 7270: train loss 2.5496, val loss 2.6796
# step 7280: train loss 2.6220, val loss 2.7066
# step 7290: train loss 2.6182, val loss 2.6963
# step 7300: train loss 2.5204, val loss 2.6295
# step 7310: train loss 2.5953, val loss 2.5577
# step 7320: train loss 2.6237, val loss 2.6798
# step 7330: train loss 2.6224, val loss 2.7103
# step 7340: train loss 2.5566, val loss 2.7741
# step 7350: train loss 2.5653, val loss 2.7223
# step 7360: train loss 2.5948, val loss 2.7011
# step 7370: train loss 2.6379, val loss 2.6915
# step 7380: train loss 2.5330, val loss 2.6894
# step 7390: train loss 2.6259, val loss 2.6272
# step 7400: train loss 2.5135, val loss 2.6414
# step 7410: train loss 2.5654, val loss 2.6049
# step 7420: train loss 2.5496, val loss 2.5808
# step 7430: train loss 2.5547, val loss 2.6594
# step 7440: train loss 2.5809, val loss 2.7587
# step 7450: train loss 2.5818, val loss 2.7225
# step 7460: train loss 2.5724, val loss 2.7581
# step 7470: train loss 2.6267, val loss 2.7141
# step 7480: train loss 2.5761, val loss 2.7748
# step 7490: train loss 2.5348, val loss 2.6101
# step 7500: train loss 2.6158, val loss 2.6722
# step 7510: train loss 2.5787, val loss 2.7305
# step 7520: train loss 2.6174, val loss 2.6952
# step 7530: train loss 2.5189, val loss 2.6179
# step 7540: train loss 2.5765, val loss 2.7223
# step 7550: train loss 2.5553, val loss 2.7131
# step 7560: train loss 2.6064, val loss 2.7025
# step 7570: train loss 2.6324, val loss 2.6219
# step 7580: train loss 2.6113, val loss 2.7950
# step 7590: train loss 2.5551, val loss 2.6756
# step 7600: train loss 2.5796, val loss 2.7559
# step 7610: train loss 2.6814, val loss 2.6948
# step 7620: train loss 2.6277, val loss 2.7662
# step 7630: train loss 2.5811, val loss 2.7431
# step 7640: train loss 2.6539, val loss 2.6751
# step 7650: train loss 2.6193, val loss 2.7846
# step 7660: train loss 2.5547, val loss 2.4810
# step 7670: train loss 2.6108, val loss 2.6373
# step 7680: train loss 2.5022, val loss 2.6135
# step 7690: train loss 2.6183, val loss 2.5883
# step 7700: train loss 2.6232, val loss 2.5346
# step 7710: train loss 2.6586, val loss 2.7087
# step 7720: train loss 2.5737, val loss 2.6388
# step 7730: train loss 2.5035, val loss 2.6257
# step 7740: train loss 2.6180, val loss 2.5620
# step 7750: train loss 2.6008, val loss 2.6109
# step 7760: train loss 2.5553, val loss 2.6679
# step 7770: train loss 2.6284, val loss 2.5712
# step 7780: train loss 2.5880, val loss 2.7643
# step 7790: train loss 2.5354, val loss 2.6294
# step 7800: train loss 2.5951, val loss 2.5529
# step 7810: train loss 2.6108, val loss 2.5757
# step 7820: train loss 2.5627, val loss 2.6991
# step 7830: train loss 2.5929, val loss 2.6342
# step 7840: train loss 2.5793, val loss 2.6057
# step 7850: train loss 2.6208, val loss 2.6825
# step 7860: train loss 2.5445, val loss 2.6822
# step 7870: train loss 2.6616, val loss 2.5853
# step 7880: train loss 2.5872, val loss 2.6896
# step 7890: train loss 2.6064, val loss 2.5999
# step 7900: train loss 2.6135, val loss 2.7081
# step 7910: train loss 2.5576, val loss 2.6321
# step 7920: train loss 2.6065, val loss 2.6181
# step 7930: train loss 2.5747, val loss 2.6269
# step 7940: train loss 2.6201, val loss 2.6575
# step 7950: train loss 2.5648, val loss 2.8049
# step 7960: train loss 2.7141, val loss 2.6925
# step 7970: train loss 2.6039, val loss 2.7202
# step 7980: train loss 2.5602, val loss 2.6836
# step 7990: train loss 2.4898, val loss 2.6345
# step 8000: train loss 2.6280, val loss 2.6509
# step 8010: train loss 2.5587, val loss 2.6911
# step 8020: train loss 2.4805, val loss 2.7380
# step 8030: train loss 2.6382, val loss 2.6709
# step 8040: train loss 2.5270, val loss 2.6109
# step 8050: train loss 2.5655, val loss 2.7346
# step 8060: train loss 2.5952, val loss 2.6583
# step 8070: train loss 2.4934, val loss 2.7471
# step 8080: train loss 2.6187, val loss 2.6917
# step 8090: train loss 2.5754, val loss 2.5584
# step 8100: train loss 2.5886, val loss 2.5995
# step 8110: train loss 2.5266, val loss 2.6708
# step 8120: train loss 2.6243, val loss 2.7705
# step 8130: train loss 2.4815, val loss 2.6702
# step 8140: train loss 2.6407, val loss 2.7193
# step 8150: train loss 2.5106, val loss 2.5996
# step 8160: train loss 2.5320, val loss 2.6969
# step 8170: train loss 2.5299, val loss 2.6548
# step 8180: train loss 2.6018, val loss 2.5808
# step 8190: train loss 2.5264, val loss 2.6758
# step 8200: train loss 2.5547, val loss 2.7140
# step 8210: train loss 2.4987, val loss 2.7306
# step 8220: train loss 2.5757, val loss 2.6658
# step 8230: train loss 2.5973, val loss 2.6276
# step 8240: train loss 2.5942, val loss 2.5132
# step 8250: train loss 2.5273, val loss 2.6448
# step 8260: train loss 2.5421, val loss 2.6089
# step 8270: train loss 2.6363, val loss 2.5900
# step 8280: train loss 2.5736, val loss 2.7502
# step 8290: train loss 2.5224, val loss 2.6446
# step 8300: train loss 2.5158, val loss 2.6350
# step 8310: train loss 2.5315, val loss 2.6058
# step 8320: train loss 2.5141, val loss 2.6441
# step 8330: train loss 2.5105, val loss 2.7335
# step 8340: train loss 2.5558, val loss 2.5721
# step 8350: train loss 2.5306, val loss 2.6281
# step 8360: train loss 2.5870, val loss 2.6214
# step 8370: train loss 2.5578, val loss 2.6227
# step 8380: train loss 2.6451, val loss 2.6326
# step 8390: train loss 2.5039, val loss 2.5811
# step 8400: train loss 2.5509, val loss 2.6626
# step 8410: train loss 2.4975, val loss 2.6189
# step 8420: train loss 2.5982, val loss 2.6321
# step 8430: train loss 2.5588, val loss 2.5805
# step 8440: train loss 2.5950, val loss 2.5549
# step 8450: train loss 2.6193, val loss 2.5894
# step 8460: train loss 2.4997, val loss 2.6233
# step 8470: train loss 2.6235, val loss 2.5690
# step 8480: train loss 2.6216, val loss 2.6226
# step 8490: train loss 2.6346, val loss 2.6820
# step 8500: train loss 2.6246, val loss 2.5429
# step 8510: train loss 2.5531, val loss 2.5694
# step 8520: train loss 2.5320, val loss 2.6251
# step 8530: train loss 2.5673, val loss 2.6508
# step 8540: train loss 2.6430, val loss 2.5893
# step 8550: train loss 2.5205, val loss 2.5524
# step 8560: train loss 2.6138, val loss 2.6565
# step 8570: train loss 2.5012, val loss 2.6374
# step 8580: train loss 2.5390, val loss 2.6684
# step 8590: train loss 2.5823, val loss 2.6007
# step 8600: train loss 2.6373, val loss 2.6203
# step 8610: train loss 2.5874, val loss 2.6510
# step 8620: train loss 2.5266, val loss 2.6666
# step 8630: train loss 2.5193, val loss 2.6855
# step 8640: train loss 2.5407, val loss 2.6205
# step 8650: train loss 2.5100, val loss 2.6189
# step 8660: train loss 2.5711, val loss 2.7211
# step 8670: train loss 2.5066, val loss 2.6442
# step 8680: train loss 2.5754, val loss 2.5180
# step 8690: train loss 2.5131, val loss 2.6694
# step 8700: train loss 2.5048, val loss 2.6837
# step 8710: train loss 2.5466, val loss 2.6400
# step 8720: train loss 2.4463, val loss 2.6564
# step 8730: train loss 2.5658, val loss 2.5740
# step 8740: train loss 2.5233, val loss 2.6122
# step 8750: train loss 2.5538, val loss 2.7104
# step 8760: train loss 2.5606, val loss 2.7088
# step 8770: train loss 2.5294, val loss 2.7190
# step 8780: train loss 2.5039, val loss 2.6473
# step 8790: train loss 2.5572, val loss 2.6292
# step 8800: train loss 2.5108, val loss 2.6740
# step 8810: train loss 2.5802, val loss 2.6031
# step 8820: train loss 2.5507, val loss 2.7256
# step 8830: train loss 2.5585, val loss 2.5343
# step 8840: train loss 2.4565, val loss 2.5632
# step 8850: train loss 2.4979, val loss 2.7586
# step 8860: train loss 2.4629, val loss 2.5854
# step 8870: train loss 2.4758, val loss 2.7183
# step 8880: train loss 2.4603, val loss 2.7082
# step 8890: train loss 2.5594, val loss 2.6786
# step 8900: train loss 2.4805, val loss 2.4925
# step 8910: train loss 2.4951, val loss 2.7097
# step 8920: train loss 2.5595, val loss 2.5461
# step 8930: train loss 2.5245, val loss 2.6119
# step 8940: train loss 2.5271, val loss 2.6477
# step 8950: train loss 2.5874, val loss 2.5596
# step 8960: train loss 2.4130, val loss 2.5975
# step 8970: train loss 2.5491, val loss 2.5271
# step 8980: train loss 2.4778, val loss 2.8334
# step 8990: train loss 2.5150, val loss 2.7119
# step 9000: train loss 2.5028, val loss 2.5756
# step 9010: train loss 2.5570, val loss 2.6654
# step 9020: train loss 2.4958, val loss 2.6551
# step 9030: train loss 2.5027, val loss 2.6201
# step 9040: train loss 2.5097, val loss 2.7493
# step 9050: train loss 2.5152, val loss 2.4539
# step 9060: train loss 2.4964, val loss 2.6973
# step 9070: train loss 2.5134, val loss 2.6214
# step 9080: train loss 2.4290, val loss 2.5776
# step 9090: train loss 2.5708, val loss 2.6164
# step 9100: train loss 2.5891, val loss 2.6636
# step 9110: train loss 2.5452, val loss 2.7372
# step 9120: train loss 2.5890, val loss 2.6610
# step 9130: train loss 2.5047, val loss 2.6225
# step 9140: train loss 2.5678, val loss 2.5865
# step 9150: train loss 2.4641, val loss 2.5169
# step 9160: train loss 2.5441, val loss 2.6191
# step 9170: train loss 2.5470, val loss 2.7114
# step 9180: train loss 2.4920, val loss 2.6309
# step 9190: train loss 2.4617, val loss 2.6464
# step 9200: train loss 2.4669, val loss 2.6882
# step 9210: train loss 2.3989, val loss 2.6209
# step 9220: train loss 2.5728, val loss 2.6170
# step 9230: train loss 2.4817, val loss 2.6466
# step 9240: train loss 2.4906, val loss 2.5187
# step 9250: train loss 2.4926, val loss 2.6562
# step 9260: train loss 2.5007, val loss 2.5860
# step 9270: train loss 2.4599, val loss 2.5837
# step 9280: train loss 2.4700, val loss 2.7175
# step 9290: train loss 2.4132, val loss 2.6919
# step 9300: train loss 2.4909, val loss 2.5253
# step 9310: train loss 2.5585, val loss 2.6201
# step 9320: train loss 2.5964, val loss 2.6014
# step 9330: train loss 2.4989, val loss 2.6352
# step 9340: train loss 2.5155, val loss 2.5762
# step 9350: train loss 2.5740, val loss 2.5664
# step 9360: train loss 2.5380, val loss 2.7264
# step 9370: train loss 2.5030, val loss 2.5475
# step 9380: train loss 2.5427, val loss 2.5240
# step 9390: train loss 2.4710, val loss 2.5627
# step 9400: train loss 2.5159, val loss 2.5768
# step 9410: train loss 2.4414, val loss 2.6728
# step 9420: train loss 2.4821, val loss 2.5874
# step 9430: train loss 2.5273, val loss 2.5716
# step 9440: train loss 2.5276, val loss 2.5350
# step 9450: train loss 2.4992, val loss 2.7289
# step 9460: train loss 2.4948, val loss 2.7379
# step 9470: train loss 2.5087, val loss 2.5444
# step 9480: train loss 2.4604, val loss 2.5621
# step 9490: train loss 2.4432, val loss 2.6124
# step 9500: train loss 2.4884, val loss 2.6473
# step 9510: train loss 2.4704, val loss 2.5540
# step 9520: train loss 2.4285, val loss 2.5549
# step 9530: train loss 2.4176, val loss 2.5921
# step 9540: train loss 2.4874, val loss 2.6878
# step 9550: train loss 2.5108, val loss 2.6081
# step 9560: train loss 2.5147, val loss 2.5134
# step 9570: train loss 2.4892, val loss 2.5954
# step 9580: train loss 2.4738, val loss 2.5541
# step 9590: train loss 2.4797, val loss 2.6862
# step 9600: train loss 2.5262, val loss 2.6603
# step 9610: train loss 2.5598, val loss 2.5493
# step 9620: train loss 2.5275, val loss 2.5978
# step 9630: train loss 2.5631, val loss 2.6238
# step 9640: train loss 2.4832, val loss 2.5976
# step 9650: train loss 2.4309, val loss 2.6272
# step 9660: train loss 2.4286, val loss 2.6766
# step 9670: train loss 2.5123, val loss 2.7127
# step 9680: train loss 2.4890, val loss 2.6200
# step 9690: train loss 2.4626, val loss 2.6675
# step 9700: train loss 2.6336, val loss 2.5409
# step 9710: train loss 2.4963, val loss 2.5193
# step 9720: train loss 2.5553, val loss 2.5664
# step 9730: train loss 2.4441, val loss 2.6135
# step 9740: train loss 2.4995, val loss 2.6176
# step 9750: train loss 2.4813, val loss 2.5752
# step 9760: train loss 2.4156, val loss 2.5880
# step 9770: train loss 2.5517, val loss 2.4927
# step 9780: train loss 2.4966, val loss 2.6075
# step 9790: train loss 2.5497, val loss 2.5128
# step 9800: train loss 2.4415, val loss 2.5447
# step 9810: train loss 2.5351, val loss 2.6346
# step 9820: train loss 2.4635, val loss 2.6221
# step 9830: train loss 2.5252, val loss 2.6159
# step 9840: train loss 2.4770, val loss 2.5765
# step 9850: train loss 2.4749, val loss 2.7097
# step 9860: train loss 2.5089, val loss 2.6003
# step 9870: train loss 2.5264, val loss 2.5108
# step 9880: train loss 2.5241, val loss 2.5477
# step 9890: train loss 2.5273, val loss 2.6785
# step 9900: train loss 2.5665, val loss 2.6614
# step 9910: train loss 2.5601, val loss 2.5654
# step 9920: train loss 2.5887, val loss 2.4967
# step 9930: train loss 2.4956, val loss 2.4796
# step 9940: train loss 2.5148, val loss 2.5648
# step 9950: train loss 2.5092, val loss 2.5565
# step 9960: train loss 2.5543, val loss 2.5476
# step 9970: train loss 2.4921, val loss 2.6064
# step 9980: train loss 2.5262, val loss 2.5776
# step 9990: train loss 2.4945, val loss 2.5068

# %% [markdown]
# Once the network has been trained for 100 iterations, we can generate a sequence of characters.
#
# #### Questions:
# - What is the effect of training?
# - Increase the number of iterations to 1,000 and then to 10,000. Note the obtained loss and the generated sentence. What do you observe?

# %%
idx = torch.ones((1,1), dtype=torch.long).to(device)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# 'ain ll!me r.
# Lèst mndens
#  à  éùue daufre  t! LÊTZ-PÊÆÀbeièvott desé;
# L--Jcs s heutalutâmelarn à l mo

# %% [markdown]
# The characters in the sentence look less random as we augment trainings iterations.

# %% [markdown]
# ## Single Head Attention
#
# We will now implement the basic attention mechanism. For each pair of words in the sequence, this mechanism combines:
# - **Q** (*query*): the information being searched for,
# - **K** (*key*): the information retrieved,
# - **V** (*value*): a result vector calculated from the attention mechanism.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masking
#
# However, since we are using the model to generate sequences, we must not use characters that come after the current character—these are precisely the characters we aim to predict during training. *The future should not be used to predict the future.*
#
# To enforce this constraint, we integrate a **masking matrix** into the process. This matrix ensures that:
# - For the first character in the sequence, only that character is available for prediction (no context).
# - For the second character, only the first and second characters can be used.
# - For the third character, only the first three characters are accessible, and so on.
#
# This results in a **lower triangular matrix**, where each row is normalized (rows sum to 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# The [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) function provides another way to achieve normalization.
#
# #### Question:
# - Verify that applying `softmax` results in the same lower triangular matrix.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implementation
#
# We can now implement the attention layer based on the following formula:
#
# ![attention_formula](images/attention_formula.png)
#
# This involves computing the **queries (Q)**, **keys (K)**, and **values (V)**, applying the **masking mechanism**, and using the **softmax function** to normalize the attention scores before computing the weighted sum of values.

# %% [markdown]
# #### Questions:
#
# - Create the **key**, **query**, and **value** layers as linear layers of dimension `C × head_size`.
# - Apply these layers to `x`.
# - Compute the attention weights:
#   ```python
#   weights = query @ key.transpose(-2, -1)
#   ```
#   (Transpose the second and third dimensions of `key` to enable matrix multiplication).
# - Apply the **normalization factor** (typically, divide by `sqrt(head_size)`).
# - Apply the **triangular mask** and the **softmax** function to `weights`.
# - Apply the **value** layer to `x`.
# - Compute the final output:
#   ```python
#   out = weights @ value(x)
#   ```

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
# define the Key layer  
key = nn.Linear(C, head_size, bias=False)
# define the Query layer
query = nn.Linear(C, head_size, bias=False)
# define the Value layer
value = nn.Linear(C, head_size, bias=False)
# apply each layer to the input
k = key(x)  # (B, T, head_size)
q = query(x)  # (B, T, head_size)
v = value(x)  # (B, T, head_size)
# compute the normalize product between Q and K 
weights = q @ k.transpose(-2, -1) * head_size**-0.5  # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril == 0, float('-inf'))
# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[ 3.7874e-01, -3.7862e-01, -7.4111e-01, -7.7779e-01,  1.2822e+00,
#           1.0911e-01,  7.1400e-01,  2.6462e-01, -6.1327e-01, -9.2476e-02,
#           1.1700e+00, -7.0283e-01, -5.4813e-01,  4.2847e-01, -3.5937e-01,
#          -2.8056e-01],
#         [ 1.8090e-01, -3.6375e-01, -6.6118e-01, -3.6596e-01,  7.1787e-01,
#           1.2589e-01,  6.3581e-01, -6.4568e-02, -3.1011e-01, -7.3287e-02,
#           3.2987e-01, -6.4707e-01,  5.4185e-02,  3.1729e-01, -2.9861e-01,
#          -5.0392e-01],
#         [ 2.7226e-01, -5.2369e-01, -3.5242e-01, -1.2546e-01,  6.4570e-01,
#           1.7942e-02,  3.8797e-01,  1.6363e-01, -4.0799e-02, -1.8124e-01,
#           2.2873e-01, -5.3024e-01,  2.1176e-01,  2.3243e-01, -8.8851e-02,
#          -6.5387e-01],
#         [ 1.1697e-01, -4.2368e-01, -2.6332e-01, -1.6307e-01,  4.6182e-01,
#          -5.6950e-02,  2.9969e-01,  3.4985e-02,  6.2810e-02,  3.1325e-02,
#           9.4684e-02, -4.1013e-01,  1.8515e-01,  1.2281e-01, -2.0532e-02,
#          -5.8187e-01],
#         [-1.6734e-02, -3.1171e-01, -3.1227e-01, -3.2488e-01,  3.8473e-01,
#           1.4400e-02,  3.1376e-01, -1.3671e-01, -1.5172e-01,  3.4885e-02,
#           1.1237e-01, -3.4761e-01,  4.0837e-02,  2.3508e-01, -5.5955e-02,
#          -3.0493e-01],
#         [-1.4952e-01,  1.3674e-02, -3.3886e-01, -3.3477e-01,  2.3224e-01,
#           3.1849e-02,  1.4573e-01, -3.5233e-01, -2.4218e-01,  8.3738e-04,
#           7.1560e-02, -4.2967e-04, -7.7285e-03,  1.4647e-01, -6.9863e-02,
#           5.2734e-02],
#         [-1.7010e-01, -7.8895e-02, -1.4551e-01, -3.5116e-01,  2.2795e-01,
#          -9.7612e-02,  1.5362e-01, -1.0390e-01, -1.3412e-01,  9.1606e-02,
#           1.4527e-01, -1.2614e-01,  2.3248e-02,  5.8871e-02,  8.5891e-02,
#          -1.0188e-01],
#         [-1.5280e-01, -4.8789e-02, -1.6903e-01, -3.5699e-01,  2.8535e-01,
#          -7.5333e-02,  5.3889e-02,  9.7571e-03, -1.0115e-01,  1.3712e-03,
#           7.3823e-02, -1.4855e-01,  6.9800e-02, -1.1831e-02,  9.5520e-02,
#          -1.8078e-01]], grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Questions:
#
# - Copy your code into `gpt_single_head.py`:
#   - Define the **key**, **query**, and **value** layers in the **constructor** of the `Head` class.
#   - Implement the **computations** in the `forward` function.
# - Train the model.
# - What are the **training** and **validation** losses?
# - Does the generated text appear **better** compared to the previous model?

# %% [markdown]
# Generetaed text : \
#  emancée vul le pupreu vele!
#  tt bre, fones norghe me  ssutombanche?
# Lencore, faulesuse fîbleux, end qu'ans on.
#  mbri voi que encr,
# L'erchanc l'à luraurr.
# Sitét de quies dommes e es hère  d'es  hema, le von! hèrerièret ndens
#  à  étu antux, a t rit, voule eisi tt des, tan-t se, heut lutentes n à hèvouieux,
# Paoù achen!
# Peu ler  fan vobren preande pr leu nevracablent deul e ge,
# L'oune chire.
# Eque,
# Oyi, meut   âpoure denourchbegll'étandes, chis, rà brtarves ffotit et e c suce
# Vointe, qu à c t fut da

# %% [markdown]
# Loss : \
# step 4999: train loss 2.3324, val loss 2.4422

# %% [markdown]
# The texte indeed appears to be better.

# %% [markdown]
# ## Multi-Head Attention
#
# Multi-head attention is simply the parallel computation of multiple **single-head attention** mechanisms. Each **single-head attention** output is concatenated to form the output of the **multi-head attention** module. In the original paper's illustration, the number of heads in the **multi-head attention** is denoted as `h`.
#
# To allow for **weighted combinations** of each single-head attention output, a **linear transformation layer** is added after concatenation.
#
# ![multi head attention](images/multi_head_attention.png)
#
# #### Questions:
#
# - In the **constructor**, create a list containing `num_heads` instances of the `Head` module using PyTorch’s [`ModuleList`](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html).
# - In the `forward` function:
#   - Apply each **single-head attention** to the input.
#   - Concatenate the results using PyTorch’s [`cat`](https://pytorch.org/docs/stable/generated/torch.cat.html) function.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, head_size * num_heads)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        # concatenate all heads' outputs
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        # apply projection and dropout
        out = self.dropout(self.proj(out))
        return out

# %% [markdown]
# #### Questions:
#
# 1. **Copy** the file `gpt_single_head.py` and rename it as `gpt_multi_head.py`.
# 2. **Add** the `MultiHeadAttention` module in `gpt_multi_head.py`.
# 3. At the **beginning of the file**, add a parameter:
#    ```python
#    n_head = 4
#    ```
# 4. In the `BigramLanguageModel` module, **replace** the `Head` module with `MultiHeadAttention`, using the parameters:
#    ```python
#    num_heads = n_head
#    head_size = n_embd // n_head
#    ```
#    This ensures the total number of parameters remains **the same**.
# 5. **Retrain the model** and note:
#    - The total number of **parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802
# ```

# %% [markdown]
# Here are the results : \
# 0.010949 M parameters \
# step 4999: train loss 2.1561, val loss 2.1703

# %% [markdown]
# ## Adding a FeedForward Computation Layer
#
# After the **attention layers**, which collect information from the sequence, a **computation layer** is added to combine all the gathered information.
#
# This layer is a simple **Multi-Layer Perceptron (MLP)** with:
# - One **hidden layer**,
# - A **ReLU non-linearity** using [`ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
#
# ### Architecture:
#
# <img src="images/multi_ff.png" alt="multi feedforward" width="200">

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### Questions:
#
# 1. **Add** the `FeedForward` module to your `gpt_multi_head.py` file.
# 2. **Integrate** this `FeedForward` layer **after** the **multi-head attention** module.
# 3. **Retrain the model** and note:
#    - The total **number of parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216
# ```

# %% [markdown]
# The results :\
# 0.019301 M parameters \
# step 4999: train loss 2.0387, val loss 2.0529

# %% [markdown]
# ## Stacking Blocks
#
# The network we have built so far represents just **one block** of the final model. Now, we can **stack multiple blocks** of **multi-head attention** to create a **deeper** network.
#
# ### Architecture:
# ![multi feedforward](images/multi_bloc.png)
#
# The following code defines a **block**:

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        # add skip connection for attention block
        x = x + self.sa(self.ln1(x))
        # add skip connection for feedforward block
        x = x + self.ffwd(self.ln2(x))
        return x

# %% [markdown]
# #### Questions:
#
# - Add the `Block` module to `gpt_multi_head.py`.
# - Modify the `BigramLanguageModel` code to include **three** instances of `Block(n_embd, n_head=4)`, using a [`Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) container **instead of** `MultiHeadAttention` and `FeedForward`.
# - Retrain the model and note:
#   - The **number of parameters**
#   - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213
# ```

# %% [markdown]
# The results : \
# 0.044709 M parameters \
# step 4999: train loss 1.8861, val loss 1.9253

# %% [markdown]
# Texte :\
#       De volus deuil un.
#
# Un fammer,
# J'on pèvre de morcheur.
# Tants n'étellaiez;
# Coes l'augrez au paube
# Ton bon.
#
#
# D'ouvre que le foie,
# Et tom l'où je pardant la fuit comb, la semomble;
# Sur des yeurs, le von!-hère luité.
# Sonsi l'oéeur dans jart! trembre comme ottit et ton boie, heuril tâce aveil homme et le fois chevakelle et ces me qui meulaière et l'étoura;
# J'ant d'elle genelles,
# L'était, que, sois moble hâme-bais nous quelle s'appeil charbreur; tête dix!
#
# Et cieux! suce bait Cosse à crimes, da

# %% [markdown]
# Le texte est beaucoup plus réaliste.

# %% [markdown]
# ## Improving Training
#
# If we want to continue increasing the **network size**, we need to incorporate layers that **enhance training stability** and **improve generalization** (reducing overfitting). These layers include:
#
# - **Skip connections** (or **residual connections**)
# - **Normalization layers**
# - **Dropout**
#
# ### Updated Architecture:
#
# <img src="images/multi_skip_norm.png" alt="multi feedforward" width="200">
#
# ---
#
# #### Questions:
#
# 1. In the `Block` module, **add a skip connection** by summing the input at each step:
#    ```python
#    x = x + self.sa(self.ln1(x))
#    x = x + self.ffwd(self.ln2(x))
#    ```
#
# 2. In the `Block` module, **add two** [`LayerNorm`](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) layers of size `n_embd`:
#    - **Before** the `Multi-Head Attention` layer.
#    - **Before** the `FeedForward` layer.
#
# 3. **After the sequence of 3 blocks**, add a **LayerNorm** layer of size `n_embd`.
#
# 4. Define a variable at the **beginning of the file**:
#    ```python
#    dropout = 0.2
#    ```
#    Then add a [`Dropout`](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer:
#    - **After** the `ReLU` activation in `FeedForward`.
#    - **After** the `Multi-Head Attention` layer in `MultiHeadAttention`.
#    - **After** the `softmax` layer in the single-head attention `Head`.
#
# 5. **Retrain the model** and note:
#    - The **number of parameters**
#    - The **training** and **validation** losses
#
# ---
#
# **Expected Output Example:**
# ```
# 0.019653 M parameters
# ```

# %% [markdown]
# The results :\
# 0.044709 M parameters \
# step 4999: train loss 1.9767, val loss 1.9921

# %% [markdown]
# ## Conclusion
#
# The key components of **GPT-2** are now in place. The next step is to **scale up** the model and train it on a **much larger** dataset. For comparison, the parameters of [GPT-2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) are:
#
# - **`vocab_size = 50257`** → GPT-2 models **subword tokens**, while we model **characters**. For us, `vocab_size = 100`.
# - **`n_positions = 1024`** → The maximum **context size**. For us, it's `block_size = 8`.
# - **`n_embd = 768`** → The **embedding dimension**. For us, it's `n_embd = 32`.
# - **`n_layer = 12`** → The number of **blocks**. For us, it's `3`.
# - **`n_head = 12`** → The number of **multi-head attention layers**. For us, it's `4`.
#
# Overall, **GPT-2** consists of **1.5 billion parameters** and was trained on **8 million web pages**, totaling **40 GB of text**.
#
# ---
#
# ### **Training Results**
# ```text
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
# ```
#
# ### **Generated Text Sample:**
#
# ```text
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
